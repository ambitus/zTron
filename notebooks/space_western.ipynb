# %% [markdown]
# https://www.starwars.com/databank

# %%
import ipywidgets as widgets

cb1 = widgets.Checkbox(description="cb1")
cb2 = widgets.Checkbox(description="cb2")
cb3 = widgets.Checkbox(description="cb3")
cb4 = widgets.Checkbox(description="cb4")

pb = widgets.Button(
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
)

def on_button_clicked(b):
    print("clicked on:",b)
    print("cb1:", cb1.value)
    print("cb2:", cb2.value)
    print("cb3:", cb3.value)
    print("cb4:", cb4.value)

pb.on_click(on_button_clicked)

ui = widgets.VBox([widgets.HBox([cb1, cb2]), widgets.HBox([cb3, cb4]),pb])

display(ui)
# Out:
# ...
# clicked on: Button(description='Click me', style=ButtonStyle(), tooltip='Click me')
# cb1: True
# cb2: False
# cb3: False
# cb4: True

# %%
import os, random, string, json

print(os.environ['PWD'])

# Being-specific attributes
beings = {'LUKESKY': ['Luke Skywalker', 700],
          'PLEIA':   ['Leia Organa', 701],
          'HANSOLO': ['Han Solo', 702],
          'CHEWY':   ['Chewbacca', 703],
          'OBIWAN':  ['Obi-wan Kenobi', 704],
          'YODA':    ['Master Yoda', 705],
          'DVADER':  ['Darth Vader', 706],
          'PADME':   ['Pamdme Amidala', 707],
          'LANDO':   ['Lando Calrissian', 708],
          'SENPALP': ['Senator Palpatine', 709],
          'BOBAFET': ['Boba Fett', 710], 
          'JABAHUT': ['Jabba the Hutt', 711],
          'GMOFFT':  ['Grand Moff Tarkin', 712],
          'GREEDO':  ['Greedo', 713],
          'BOSSK':   ['Bossk', 714],
          'MACEWND': ['Mace Windu', 715],
          'DSIDOUS': ['Darth Sidious', 716],
          'DMAUL':   ['Darth Maul', 717],
          'QUIGONJ': ['Qui-Gon Jinn', 718],
          'WATTO':   ['Watto', 719],
          'NUTEGUN': ['Nute Gunray', 720],
          'LOTTDOD': ['Lott Dod', 721],
          'SHIMSKY': ['Shimi Skywalker Lars', 722],
          'JANGFET': ['Jango Fett', 723],
          'OWENLRS': ['Owen Lars', 724],
          'BAILORG': ['Bail Organa', 725],
          'REY':     ['Rey', 726],
          'FINN':    ['Finn', 727],
          'POEDAM':  ['Poe Dameron', 728],
          'KYLOREN': ['Supreme Leader Kylo Ren', 729],
          'GHUX':    ['General Hux', 730],
          'MAZKANT': ['Maz Kanata', 731],
          'SNOKE':   ['Supreme Leader Snoke', 732],
          'PHASMA':  ['Captain Phasma', 733],
          'BALATIK': ['Bala Tik', 734],
          'DJ':      ['DJ', 735],
          'ADAKBAR': ['Admiral Akbar', 736],
          'ROSETIC': ['Rose Tico', 737],
          'JANNAH':  ['Jannah', 738],
          'BABUFRK': ['Babu Frik', 739],
          'NIENUNB': ['Nien Nunb', 740],
          'ZORIBLS': ['Zorii Bliss', 741]
         }

# Common attributes
common_being_attrs = {
                      'base:password': '',
                      'base:owner': '',
                      'base:special': False,
                      'base:operations': True,
                      'omvs:program': '/bin/sh'
                     }

groups = {'rebels': [['LUKESKY', 'PLEIA', 'HANSOLO', 'CHEWY', 'OBIWAN', 
                     'YODA', 'PADME', 'LANDO', 'MACEWND', 'QUIGONJ',
                     'SHIMSKY', 'OWENLRS', 'BAILORG', 'REY', 'FINN',
                     'POEDAM', 'MAZKANT', 'ADAKBAR', 'ROSETIC', 'JANNAH'
                     'NIENUNB', 'ZORIBLS'], 600],
          'empire': [['DVADER', 'SENPALP', 'DSIDOUS', 'KYLOREN', 'GHUX'
                     'SNOKE', 'PHASMA'], 601],
          'first order': [['KYLOREN', 'GHUX', 'PHASMA', 'SNOKE'], 602],
          'republic': [['SENPALP', 'NUTEGUN', 'LOTTDOD'], 603],
          'sith': [['DSIDOUS', 'DMAUL', 'DVADER'], 604],
          'jedi': [['YODA', 'OBIWAN', 'QUIGONJ', 'MACEWND'], 605],
          'gangsters': [['JABAHUT', 'NUTEGUN', 'LOTTDOD', 'DJ'], 606],
          'Mandalorians': [['BOBAFET', 'JANGFET'], 607],
          'Scoundrels': [['HANSOLO', 'LANDO', 'BOBAFET', 'JANGFET', 'BALATIK',
                         'POEDAM', 'DJ', 'BABUFRK', 'WATTO'],608]}

droids   = ['C-3PO', 'R2-D2', 'R5-D4', 'R4-P17', 'BB-8', 'BB-9E', 'D-O']
species  = ['human', 'wookiee', 'jawa', 'sullustan', 'ewok' 'hutt', 'gungan']
vehicles = ['x-wing', 'tie fighter', 'speeder', 'pod racer', 'death star']
weapons  = ['light saber', 'blaster']
planets  = ['Alderaan', 'Tatooine', 'Hoth', 'Dagobah', 'Endor', 'Naboo'
            'Corsucant', 'Geonosis', 'Jakku', 'Ahch-To', 'Cantonica', 'Exegol']

COMMON_PWD_LEN = 8


#
# Utilities
#
def generate_password(pwd_len):
     pwd = ''
     letters = string.ascii_letters + string.digits + '_-*'
     return pwd.join(random.choice(letters) for i in range(pwd_len))



#
# Mainline
#
# This user will become the owner for all defined resources.
if (os.environ['USER'] == None):
    print()
    
# Add groups
for n, i in groups.items():
    print('group: %s,   GID: %d' % (n, i[1]))
    print('   members: %s' % (i[0]))
print('')

# Add users
for n, i in beings.items():
    print('name %s,   ID: %s' % (i[0], n))
    print('   UID: %d:,   pwd: %s' % (i[1], generate_password(COMMON_PWD_LEN)))
print('')
# Out:
# /
# group: rebels,   GID: 600
#    members: ['LUKESKY', 'PLEIA', 'HANSOLO', 'CHEWY', 'OBIWAN', 'YODA', 'PADME', 'LANDO', 'MACEWND', 'QUIGONJ', 'SHIMSKY', 'OWENLRS', 'BAILORG', 'REY', 'FINN', 'POEDAM', 'MAZKANT', 'ADAKBAR', 'ROSETIC', 'JANNAHNIENUNB', 'ZORIBLS']
# group: empire,   GID: 601
#    members: ['DVADER', 'SENPALP', 'DSIDOUS', 'KYLOREN', 'GHUXSNOKE', 'PHASMA']
# group: first order,   GID: 602
#    members: ['KYLOREN', 'GHUX', 'PHASMA', 'SNOKE']
# group: republic,   GID: 603
#    members: ['SENPALP', 'NUTEGUN', 'LOTTDOD']
# group: sith,   GID: 604
#    members: ['DSIDOUS', 'DMAUL', 'DVADER']
# group: jedi,   GID: 605
#    members: ['YODA', 'OBIWAN', 'QUIGONJ', 'MACEWND']
# group: gangsters,   GID: 606
#    members: ['JABAHUT', 'NUTEGUN', 'LOTTDOD', 'DJ']
# group: Mandalorians,   GID: 607
#    members: ['BOBAFET', 'JANGFET']
# group: Scoundrels,   GID: 608
#    members: ['HANSOLO', 'LANDO', 'BOBAFET', 'JANGFET', 'BALATIK', 'POEDAM', 'DJ', 'BABUFRK', 'WATTO']
#
# ...

# %%
# Serialize the configuration
print(json.dumps(groups, indent=3))
print('-----------')
print(json.dumps(beings, indent=3))
# Out:
# {
#    "rebels": [
#       [
#          "LUKESKY",
#          "PLEIA",
#          "HANSOLO",
#          "CHEWY",
#          "OBIWAN",
#          "YODA",
#          "PADME",
#          "LANDO",
#          "MACEWND",
#          "QUIGONJ",
#          "SHIMSKY",
#          "OWENLRS",
#          "BAILORG",
#          "REY",
#          "FINN",
#          "POEDAM",
#          "MAZKANT",
#          "ADAKBAR",
#          "ROSETIC",
#          "JANNAHNIENUNB",
#          "ZORIBLS"
#       ],
#       600
#    ],
#    "empire": [
#       [
#          "DVADER",
#          "SENPALP",
#          "DSIDOUS",
#          "KYLOREN",
#          "GHUXSNOKE",
#          "PHASMA"
#       ],
#       601
#    ],
#    "first order": [
#       [
#          "KYLOREN",
#          "GHUX",
#          "PHASMA",
#          "SNOKE"
#       ],
#       602
#    ],
#    "republic": [
#       [
#          "SENPALP",
#          "NUTEGUN",
#          "LOTTDOD"
#       ],
#       603
#    ],
#    "sith": [
#       [
# ...

# %%
# Build fields for defining a user.
user_id = widgets.Text(description='Userid', placeholder='required' )
user_name = widgets.Text(description='User\'s Name', placeholder='required')
attr_special = widgets.Checkbox(description='Special')
attr_operations = widgets.Checkbox(description="Operations")
attr_omvs = widgets.Checkbox(description="z/OS Unix")
attr_tso = widgets.Checkbox(description="TSO")

# Create a push button to add the user.
pb = widgets.Button(
    description='Create User',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click to create a user'
)

# Create check boxes for the attribute fields. 
checkboxes = widgets.VBox([widgets.HBox([attr_special, attr_operations]),
                           widgets.HBox([attr_omvs, attr_tso]),
                           pb])

# The event handler that gets control when the user pushes the go button.
def on_button_click(b):
    print('Userid:    %s' % (user_id.value))
    print('User name: %s' % (user_name.value))
    print('User attributes:')
    attrs = '   '
    if (attr_special.value):
        attrs += 'special   '
    if (attr_operations.value):
        attrs += 'operations   '
    if (attr_omvs.value):
        attrs += 'z/OS Unix   '
    if (attr_tso.value):
        attrs += 'TSO'
    if (attrs != ''):
        print(attrs)

# Display the form and wait for a response.
display(user_name, user_id, checkboxes)
pb.on_click(on_button_click)
# Out:
# Text(value='', description="User's Name", placeholder='required')
# Text(value='', description='Userid', placeholder='required')
# ...
# Userid:    bfett
# User name: Bubba Fett
# User attributes:
#    special   z/OS Unix   TSO
